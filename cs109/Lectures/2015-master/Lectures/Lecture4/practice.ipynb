# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
import seaborn as sns

# %%
ourschema="""
DROP TABLE IF EXISTS "candidates";
DROP TABLE IF EXISTS "contributors";
CREATE TABLE "candidates" (
    "id" INTEGER PRIMARY KEY  NOT NULL ,
    "first_name" VARCHAR,
    "last_name" VARCHAR,
    "middle_name" VARCHAR,
    "party" VARCHAR NOT NULL
);
CREATE TABLE "contributors" (
    "id" INTEGER PRIMARY KEY  AUTOINCREMENT  NOT NULL,
    "last_name" VARCHAR,
    "first_name" VARCHAR,
    "middle_name" VARCHAR,
    "street_1" VARCHAR,
    "street_2" VARCHAR,
    "city" VARCHAR,
    "state" VARCHAR,
    "zip" VARCHAR,
    "amount" INTEGER,
    "date" DATETIME,
    "candidate_id" INTEGER NOT NULL,
    FOREIGN KEY(candidate_id) REFERENCES candidates(id)
);
"""

# %%
from sqlite3 import dbapi2 as sq3
import os
PATHSTART="."
def get_db(dbfile):
    sqlite_db = sq3.connect(os.path.join(PATHSTART,dbfile))
    return sqlite_db

# %%
def init_db(dbfile,schema):
    db = get_db(dbfile)
    db.cursor().executescript(schema)
    db.commit()
    return db

# %%
dfcand=pd.read_csv("./candidates.txt",sep='|')
dfcand
# Out:
#     id   first_name   last_name middle_name party
# 0   33       Joseph       Biden         NaN     D
# 1   36       Samuel   Brownback         NaN     R
# 2   34      Hillary     Clinton          R.     D
# 3   39  Christopher        Dodd          J.     D
# 4   26         John     Edwards         NaN     D
# 5   22      Rudolph    Giuliani         NaN     R
# 6   24         Mike      Gravel         NaN     D
# 7   16         Mike    Huckabee         NaN     R
# 8   30       Duncan      Hunter         NaN     R
# 9   31       Dennis    Kucinich         NaN     D
# 10  37         John      McCain         NaN     R
# 11  20       Barack       Obama         NaN     D
# 12  32          Ron        Paul         NaN     R
# 13  29         Bill  Richardson         NaN     D
# 14  35         Mitt      Romney         NaN     R
# 15  38          Tom    Tancredo         NaN     R
# 16  41         Fred    Thompson          D.     R

# %%
dfcwci=pd.read_csv("./contributors_with_candidate_id.txt",sep="|")
dfcwci.head()
# Out:
#    id last_name first_name middle_name                street_1 street_2  \
# 0 NaN      Agee     Steven         NaN  549 Laurel Branch Road      NaN
# 1 NaN    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 2 NaN    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 3 NaN    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 4 NaN      Akin    Charles         NaN  10187 Sugar Creek Road      NaN
#
#           city state    zip  amount        date  candidate_id
# 0        Floyd    VA  24091     500  2007-06-30            16
# 1   Pleasanton    CA  94566     250  2007-05-16            16
# 2   Pleasanton    CA  94566      50  2007-06-18            16
# 3   Pleasanton    CA  94566     100  2007-06-21            16
# 4  Bentonville    AR  72712     100  2007-06-16            16

# %%
dfcwci.columns
dfcwci=dfcwci.drop("id",axis=1)

# %%
dfcwci.head()
# Out:
#   last_name first_name middle_name                street_1 street_2  \
# 0      Agee     Steven         NaN  549 Laurel Branch Road      NaN
# 1    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 2    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 3    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 4      Akin    Charles         NaN  10187 Sugar Creek Road      NaN
#
#           city state    zip  amount        date  candidate_id
# 0        Floyd    VA  24091     500  2007-06-30            16
# 1   Pleasanton    CA  94566     250  2007-05-16            16
# 2   Pleasanton    CA  94566      50  2007-06-18            16
# 3   Pleasanton    CA  94566     100  2007-06-21            16
# 4  Bentonville    AR  72712     100  2007-06-16            16

# %%
db=init_db("cancont.db",ourschema)

# %% [markdown]
# Add Pandas Dataframe to Database

# %%
dfcand.to_sql("candidates",db,if_exists="append",index=False)

# %%
dfcwci.to_sql("contributors",db,if_exists="append",index=False)

# %%
dfcwci.shape
# Out:
# (175, 11)

# %%
sel="select * from candidates;"
c=db.cursor().execute(sel)

# %%
c.fetchall()
# Out:
# [(16, u'Mike', u'Huckabee', None, u'R'),
#  (20, u'Barack', u'Obama', None, u'D'),
#  (22, u'Rudolph', u'Giuliani', None, u'R'),
#  (24, u'Mike', u'Gravel', None, u'D'),
#  (26, u'John', u'Edwards', None, u'D'),
#  (29, u'Bill', u'Richardson', None, u'D'),
#  (30, u'Duncan', u'Hunter', None, u'R'),
#  (31, u'Dennis', u'Kucinich', None, u'D'),
#  (32, u'Ron', u'Paul', None, u'R'),
#  (33, u'Joseph', u'Biden', None, u'D'),
#  (34, u'Hillary', u'Clinton', u'R.', u'D'),
#  (35, u'Mitt', u'Romney', None, u'R'),
#  (36, u'Samuel', u'Brownback', None, u'R'),
#  (37, u'John', u'McCain', None, u'R'),
#  (38, u'Tom', u'Tancredo', None, u'R'),
#  (39, u'Christopher', u'Dodd', u'J.', u'D'),
#  (41, u'Fred', u'Thompson', u'D.', u'R')]

# %%
rem="Delete from candidates;"
c=db.cursor().execute(rem)
db.commit()

# %%
c.fetchall()
# Out:
# []

# %%
ins="insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?)"
with open("candidates.txt") as fd:
    slines = [l.strip().split("|") for l in fd.readlines()]
    for line in slines[1:]:
        theid, first_name, last_name, middle_name, party = line
        print theid, first_name, last_name, middle_name, party
        valstoinsert = (int(theid),first_name,last_name,middle_name,party)
        print ins, valstoinsert
        db.cursor().execute(ins,valstoinsert)
# Out:
# 33 Joseph Biden  D
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (33, 'Joseph', 'Biden', '', 'D')
# 36 Samuel Brownback  R
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (36, 'Samuel', 'Brownback', '', 'R')
# 34 Hillary Clinton R. D
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (34, 'Hillary', 'Clinton', 'R.', 'D')
# 39 Christopher Dodd J. D
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (39, 'Christopher', 'Dodd', 'J.', 'D')
# 26 John Edwards  D
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (26, 'John', 'Edwards', '', 'D')
# 22 Rudolph Giuliani  R
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (22, 'Rudolph', 'Giuliani', '', 'R')
# 24 Mike Gravel  D
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (24, 'Mike', 'Gravel', '', 'D')
# 16 Mike Huckabee  R
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (16, 'Mike', 'Huckabee', '', 'R')
# 30 Duncan Hunter  R
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (30, 'Duncan', 'Hunter', '', 'R')
# 31 Dennis Kucinich  D
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (31, 'Dennis', 'Kucinich', '', 'D')
# 37 John McCain  R
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (37, 'John', 'McCain', '', 'R')
# 20 Barack Obama  D
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (20, 'Barack', 'Obama', '', 'D')
# 32 Ron Paul  R
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (32, 'Ron', 'Paul', '', 'R')
# 29 Bill Richardson  D
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (29, 'Bill', 'Richardson', '', 'D')
# 35 Mitt Romney  R
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (35, 'Mitt', 'Romney', '', 'R')
# 38 Tom Tancredo  R
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (38, 'Tom', 'Tancredo', '', 'R')
# 41 Fred Thompson D. R
# insert into candidates (id,first_name,last_name,middle_name, party) values (?,?,?,?,?) (41, 'Fred', 'Thompson', 'D.', 'R')

# %%
def make_query(sel):
    c = db.cursor().execute(sel)
    return c.fetchall()

# %%
make_query("select * from candidates;")
# Out:
# [(16, u'Mike', u'Huckabee', u'', u'R'),
#  (20, u'Barack', u'Obama', u'', u'D'),
#  (22, u'Rudolph', u'Giuliani', u'', u'R'),
#  (24, u'Mike', u'Gravel', u'', u'D'),
#  (26, u'John', u'Edwards', u'', u'D'),
#  (29, u'Bill', u'Richardson', u'', u'D'),
#  (30, u'Duncan', u'Hunter', u'', u'R'),
#  (31, u'Dennis', u'Kucinich', u'', u'D'),
#  (32, u'Ron', u'Paul', u'', u'R'),
#  (33, u'Joseph', u'Biden', u'', u'D'),
#  (34, u'Hillary', u'Clinton', u'R.', u'D'),
#  (35, u'Mitt', u'Romney', u'', u'R'),
#  (36, u'Samuel', u'Brownback', u'', u'R'),
#  (37, u'John', u'McCain', u'', u'R'),
#  (38, u'Tom', u'Tancredo', u'', u'R'),
#  (39, u'Christopher', u'Dodd', u'J.', u'D'),
#  (41, u'Fred', u'Thompson', u'D.', u'R')]

# %%
rem="""
DELETE FROM candidates;
"""
c = db.cursor().execute(rem)
db.commit()

# %%
# %%bash
# tail -n +2 candidates.txt > candidates_nohead.txt
# echo ".import candidates_nohead_txt candidates" | sqlite3 cancont.db
# Out:
# Couldn't find program: u'bash'

# %%
dfcwci.head()
# Out:
#   last_name first_name middle_name                street_1 street_2  \
# 0      Agee     Steven         NaN  549 Laurel Branch Road      NaN
# 1    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 2    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 3    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 4      Akin    Charles         NaN  10187 Sugar Creek Road      NaN
#
#           city state    zip  amount        date  candidate_id
# 0        Floyd    VA  24091     500  2007-06-30            16
# 1   Pleasanton    CA  94566     250  2007-05-16            16
# 2   Pleasanton    CA  94566      50  2007-06-18            16
# 3   Pleasanton    CA  94566     100  2007-06-21            16
# 4  Bentonville    AR  72712     100  2007-06-16            16

# %%
dfcwci.query("state=='VA' & amount < 400")
# Out:
#      last_name first_name middle_name                     street_1 street_2  \
# 27    Buckheit      Bruce         NaN                8904 KAREN DR      NaN
# 77   Ranganath      Anoop         NaN           2507 Willard Drive      NaN
# 88   Perreault     Louise         NaN    503 Brockridge Hunt Drive      NaN
# 145    ABDELLA     THOMAS          M.  4231 MONUMENT WALL WAY #340      NaN
#
#                 city state        zip  amount        date  candidate_id
# 27           FAIRFAX    VA  220312731  100.00  2007-09-19            20
# 77   Charlottesville    VA      22903 -100.00  2008-04-21            32
# 88           Hampton    VA      23666  -34.08  2008-04-21            32
# 145          FAIRFAX    VA  220308440   50.00  2007-09-30            35

# %%
dfcwci[(dfcwci.state=='VA')&(dfcwci.amount<400)]
# Out:
#      last_name first_name middle_name                     street_1 street_2  \
# 27    Buckheit      Bruce         NaN                8904 KAREN DR      NaN
# 77   Ranganath      Anoop         NaN           2507 Willard Drive      NaN
# 88   Perreault     Louise         NaN    503 Brockridge Hunt Drive      NaN
# 145    ABDELLA     THOMAS          M.  4231 MONUMENT WALL WAY #340      NaN
#
#                 city state        zip  amount        date  candidate_id
# 27           FAIRFAX    VA  220312731  100.00  2007-09-19            20
# 77   Charlottesville    VA      22903 -100.00  2008-04-21            32
# 88           Hampton    VA      23666  -34.08  2008-04-21            32
# 145          FAIRFAX    VA  220308440   50.00  2007-09-30            35

# %%
cont_cols = [e[1] for e in make_query("PRAGMA table_info(contributors);")]

# %%
cont_cols
# Out:
# [u'id',
#  u'last_name',
#  u'first_name',
#  u'middle_name',
#  u'street_1',
#  u'street_2',
#  u'city',
#  u'state',
#  u'zip',
#  u'amount',
#  u'date',
#  u'candidate_id']

# %%
def make_frame(list_of_tuples, legend=cont_cols):
    framelist=[]
    for i, cname in enumerate(legend):
        framelist.append((cname,[e[i] for e in list_of_tuples]))
        
    return pd.DataFrame.from_items(framelist)

# %%
out = make_query("SELECT * FROM contributors WHERE state='VA' AND amount < 400;")
make_frame(out)
# Out:
#     id  last_name first_name middle_name                     street_1  \
# 0   28   Buckheit      Bruce        None                8904 KAREN DR
# 1   78  Ranganath      Anoop        None           2507 Willard Drive
# 2   89  Perreault     Louise        None    503 Brockridge Hunt Drive
# 3  146    ABDELLA     THOMAS          M.  4231 MONUMENT WALL WAY #340
#
#   street_2             city state        zip  amount        date  candidate_id
# 0     None          FAIRFAX    VA  220312731  100.00  2007-09-19            20
# 1     None  Charlottesville    VA      22903 -100.00  2008-04-21            32
# 2     None          Hampton    VA      23666  -34.08  2008-04-21            32
# 3     None          FAIRFAX    VA  220308440   50.00  2007-09-30            35

# %%
out = make_query("SELECT * FROM contributors WHERE state IS NULL;")
make_frame(out)
# Out:
#     id last_name first_name middle_name       street_1 street_2        city  \
# 0  126    BOURNE     TRAVIS        None  LAGE KAART 77     None  BRASSCHATT
#
#   state   zip  amount        date  candidate_id
# 0  None  2930    -500  2008-11-20            35

# %%
dfcwci[dfcwci.state.isnull()]
# Out:
#     last_name first_name middle_name       street_1 street_2        city  \
# 125    BOURNE     TRAVIS         NaN  LAGE KAART 77      NaN  BRASSCHATT
#
#     state   zip  amount        date  candidate_id
# 125   NaN  2930    -500  2008-11-20            35

# %%
out = make_query("SELECT * FROM contributors WHERE state IS NOT NULL;")
make_frame(out).shape
# Out:
# (174, 12)

# %%
dfcwci[dfcwci.state.notnull()].shape
# Out:
# (174, 11)

# %%
out=make_query("SELECT * FROM contributors WHERE state IN ('VA','WA');")
make_frame(out).head(10)
# Out:
#     id  last_name first_name middle_name                      street_1  \
# 0    1       Agee     Steven        None        549 Laurel Branch Road
# 1   28   Buckheit      Bruce        None                 8904 KAREN DR
# 2   63      BURKE    SUZANNE          M.                 3401 EVANSTON
# 3   78  Ranganath      Anoop        None            2507 Willard Drive
# 4   89  Perreault     Louise        None     503 Brockridge Hunt Drive
# 5  101   Aaronson    Rebecca        None  2000 Village Green Dr Apt 12
# 6  107   Aaronson    Rebecca        None  2000 Village Green Dr Apt 12
# 7  146    ABDELLA     THOMAS          M.   4231 MONUMENT WALL WAY #340
#
#   street_2             city state        zip  amount        date  candidate_id
# 0     None            Floyd    VA      24091  500.00  2007-06-30            16
# 1     None          FAIRFAX    VA  220312731  100.00  2007-09-19            20
# 2     None          SEATTLE    WA  981038677 -700.00  2008-03-05            22
# 3     None  Charlottesville    VA      22903 -100.00  2008-04-21            32
# 4     None          Hampton    VA      23666  -34.08  2008-04-21            32
# 5     None       Mill Creek    WA  980125787  100.00  2008-02-08            34
# 6     None       Mill Creek    WA  980125787  100.00  2008-02-14            34
# 7     None          FAIRFAX    VA  220308440   50.00  2007-09-30            35

# %%
dfcwci[dfcwci.state.isin(['VA','WA'])].head(10)
# Out:
#      last_name first_name middle_name                      street_1 street_2  \
# 0         Agee     Steven         NaN        549 Laurel Branch Road      NaN
# 27    Buckheit      Bruce         NaN                 8904 KAREN DR      NaN
# 62       BURKE    SUZANNE          M.                 3401 EVANSTON      NaN
# 77   Ranganath      Anoop         NaN            2507 Willard Drive      NaN
# 88   Perreault     Louise         NaN     503 Brockridge Hunt Drive      NaN
# 100   Aaronson    Rebecca         NaN  2000 Village Green Dr Apt 12      NaN
# 106   Aaronson    Rebecca         NaN  2000 Village Green Dr Apt 12      NaN
# 145    ABDELLA     THOMAS          M.   4231 MONUMENT WALL WAY #340      NaN
#
#                 city state        zip  amount        date  candidate_id
# 0              Floyd    VA      24091  500.00  2007-06-30            16
# 27           FAIRFAX    VA  220312731  100.00  2007-09-19            20
# 62           SEATTLE    WA  981038677 -700.00  2008-03-05            22
# 77   Charlottesville    VA      22903 -100.00  2008-04-21            32
# 88           Hampton    VA      23666  -34.08  2008-04-21            32
# 100       Mill Creek    WA  980125787  100.00  2008-02-08            34
# 106       Mill Creek    WA  980125787  100.00  2008-02-14            34
# 145          FAIRFAX    VA  220308440   50.00  2007-09-30            35

# %%
out = make_query("SELECT * FROM contributors WHERE amount BETWEEN 10 AND 50;")
make_frame(out).head(10)
# Out:
#     id last_name first_name middle_name                    street_1 street_2  \
# 0    3    Ahrens        Don        None        4034 Rennellwood Way     None
# 1   19     Ardle    William        None           412 Dakota Avenue     None
# 2   26   Buckler      Steve        None             24351 Armada Dr     None
# 3   27   Buckler      Steve        None             24351 Armada Dr     None
# 4   35      Buck    Barbara        None            1780 NE 138th St     None
# 5   36      Buck    Barbara        None            1780 NE 138th St     None
# 6   39  Buchanek  Elizabeth        None            7917 Kentbury Dr     None
# 7   50  Harrison       Ryan        None                 2247 3rd St     None
# 8  102    Aarons     Elaine        None  481 Buck Island Rd Apt 17A  APT 17A
# 9  105     Aaron    Shirley        None              101 Cherry Ave     None
#
#             city state        zip  amount        date  candidate_id
# 0     Pleasanton    CA      94566      50  2007-06-18            16
# 1    Springfield    OH      45504      50  2007-06-28            16
# 2     Dana Point    CA  926291306      50  2007-07-30            20
# 3     Dana Point    CA  926291306      25  2007-08-16            20
# 4    North Miami    FL  331811316      50  2007-09-13            20
# 5    North Miami    FL  331811316      50  2007-07-19            20
# 6       Bethesda    MD  208144615      50  2007-09-30            20
# 7       La Verne    CA  917504918      25  2007-07-26            20
# 8  West Yarmouth    MA   26733300      25  2008-02-26            34
# 9         Havana    FL  323331311      50  2008-02-29            34

# %%
dfcwci.query("10<=amount<=50").head(10)
# Out:
#     last_name first_name middle_name                    street_1 street_2  \
# 2      Ahrens        Don         NaN        4034 Rennellwood Way      NaN
# 18      Ardle    William         NaN           412 Dakota Avenue      NaN
# 25    Buckler      Steve         NaN             24351 Armada Dr      NaN
# 26    Buckler      Steve         NaN             24351 Armada Dr      NaN
# 34       Buck    Barbara         NaN            1780 NE 138th St      NaN
# 35       Buck    Barbara         NaN            1780 NE 138th St      NaN
# 38   Buchanek  Elizabeth         NaN            7917 Kentbury Dr      NaN
# 49   Harrison       Ryan         NaN                 2247 3rd St      NaN
# 101    Aarons     Elaine         NaN  481 Buck Island Rd Apt 17A  APT 17A
# 104     Aaron    Shirley         NaN              101 Cherry Ave      NaN
#
#               city state        zip  amount        date  candidate_id
# 2       Pleasanton    CA      94566      50  2007-06-18            16
# 18     Springfield    OH      45504      50  2007-06-28            16
# 25      Dana Point    CA  926291306      50  2007-07-30            20
# 26      Dana Point    CA  926291306      25  2007-08-16            20
# 34     North Miami    FL  331811316      50  2007-09-13            20
# 35     North Miami    FL  331811316      50  2007-07-19            20
# 38        Bethesda    MD  208144615      50  2007-09-30            20
# 49        La Verne    CA  917504918      25  2007-07-26            20
# 101  West Yarmouth    MA   26733300      25  2008-02-26            34
# 104         Havana    FL  323331311      50  2008-02-29            34

# %%
dfcwci.sort("amount").head(10)
# Out:
# C:\Users\Kevin\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#    last_name   first_name middle_name                      street_1 street_2  \
# 90     Kazor  Christopher           M           707 Spindletree ave      NaN
# 72     BRUNO         JOHN         NaN  10136 WINDERMERE CHASE BLVD.      NaN
# 64     BURKE       DONALD          J.                     12 LOMPOC      NaN
# 73     BRUNO        IRENE         NaN  10136 WINDERMERE CHASE BLVD.      NaN
# 74     BROWN      TIMOTHY          J.           26826 MARLOWE COURT      NaN
# 58    BURTON        GLENN          M.         4404 CHARLESTON COURT      NaN
# 57    BURTON       STEVEN          G.         9938 DEER CREEK DRIVE      NaN
# 84   Uihlein      Richard         NaN            1396 N Waukegan Rd      NaN
# 56    BURTON        SUSAN         NaN         9338 DEER CREEK DRIVE      NaN
# 55      BUSH         ERIC         NaN                P.O. BOX 61046      NaN
#
#                   city state        zip  amount        date  candidate_id
# 90          Naperville    IL      60565   -2592  2008-04-21            32
# 72               GOTHA    FL  347344707   -2300  2008-03-06            22
# 64  RANCHO SANTA MARGA    CA  926881817   -2300  2008-03-11            22
# 73               GOTHA    FL  347344707   -2300  2008-03-06            22
# 74     STEVENSON RANCH    CA  913811020   -2300  2008-03-06            22
# 58               TAMPA    FL  336092620   -2300  2008-03-05            22
# 57               TAMPA    FL      33647   -2300  2008-03-05            22
# 84         Lake Forest    IL  600451147   -2300  2008-04-21            32
# 56               TAMPA    FL  336472286   -2300  2008-03-05            22
# 55              DENVER    CO  802061046   -2300  2008-03-06            22

# %%
dfcwci.sort_values(by="amount",ascending=False).head(10)
# Out:
#       last_name first_name middle_name                 street_1 street_2  \
# 30       Buckel      Linda         NaN            PO Box 683130      NaN
# 159       ABATE      MARIA       ELENA  1291 NIGHTINGALE AVENUE      NaN
# 15      Anthony       John         NaN    211 Long Island Drive      NaN
# 33         Buck     Blaine           M             45 Eaton Ave      NaN
# 28       Buckel      Linda         NaN            PO Box 683130      NaN
# 21        Baker      David         NaN   2550 Adamsbrooke Drive      NaN
# 13        Altes       R.D.         NaN          8600 Moody Road      NaN
# 135  ABRAMOWITZ       NIRA         NaN          411 HARBOR ROAD      NaN
# 5          Akin       Mike         NaN         181 Baywood Lane      NaN
# 174     ABRAHAM      SALEM          A.               P.O. BOX 7      NaN
#
#               city state        zip  amount        date  candidate_id
# 30       Park City    UT  840683130    4600  2007-08-14            20
# 159  MIAMI SPRINGS    FL  331663832    2600  2008-01-25            37
# 15     Hot Springs    AR      71913    2300  2007-06-12            16
# 33          Camden    ME   48431752    2300  2007-09-30            20
# 28       Park City    UT  840683130    2300  2007-08-14            20
# 21          Conway    AR      72034    2300  2007-04-11            16
# 13      Fort Smith    AR      72903    2300  2007-06-21            16
# 135      SOUTHPORT    CT   68901376    2300  2007-09-14            35
# 5       Monticello    AR      71655    1500  2007-05-18            16
# 174       CANADIAN    TX  790140007    1300  2008-01-30            37

# %%
out = make_query("SELECT * FROM contributors ORDER BY amount")
make_frame(out).head(10)
# Out:
#    id last_name   first_name middle_name                   street_1 street_2  \
# 0  91     Kazor  Christopher           M        707 Spindletree ave     None
# 1  30    Buckel        Linda        None              PO Box 683130     None
# 2  52  BYINGTON     MARGARET          E.  2633 MIDDLEBORO LANE N.E.     None
# 3  53     BYERS          BOB          A.       13170 TELFAIR AVENUE     None
# 4  55      BUSH      KRYSTIE        None             P.O. BOX 61046     None
# 5  56      BUSH         ERIC        None             P.O. BOX 61046     None
# 6  57    BURTON        SUSAN        None      9338 DEER CREEK DRIVE     None
# 7  58    BURTON       STEVEN          G.      9938 DEER CREEK DRIVE     None
# 8  59    BURTON        GLENN          M.      4404 CHARLESTON COURT     None
# 9  65     BURKE       DONALD          J.                  12 LOMPOC     None
#
#                  city state        zip  amount        date  candidate_id
# 0          Naperville    IL      60565   -2592  2008-04-21            32
# 1           Park City    UT  840683130   -2300  2007-08-14            20
# 2        GRAND RAPIDS    MI  495061254   -2300  2008-03-03            22
# 3              SYLMAR    CA  913423573   -2300  2008-03-07            22
# 4              DENVER    CO  802061046   -2300  2008-03-06            22
# 5              DENVER    CO  802061046   -2300  2008-03-06            22
# 6               TAMPA    FL  336472286   -2300  2008-03-05            22
# 7               TAMPA    FL      33647   -2300  2008-03-05            22
# 8               TAMPA    FL  336092620   -2300  2008-03-05            22
# 9  RANCHO SANTA MARGA    CA  926881817   -2300  2008-03-11            22

# %%
out = make_query("SELECT * FROM contributors ORDER BY amount DESC;")
make_frame(out).head(10)
# Out:
#     id   last_name first_name middle_name                 street_1 street_2  \
# 0   31      Buckel      Linda        None            PO Box 683130     None
# 1  160       ABATE      MARIA       ELENA  1291 NIGHTINGALE AVENUE     None
# 2   14       Altes       R.D.        None          8600 Moody Road     None
# 3   16     Anthony       John        None    211 Long Island Drive     None
# 4   22       Baker      David        None   2550 Adamsbrooke Drive     None
# 5   29      Buckel      Linda        None            PO Box 683130     None
# 6   34        Buck     Blaine           M             45 Eaton Ave     None
# 7  136  ABRAMOWITZ       NIRA        None          411 HARBOR ROAD     None
# 8    6        Akin       Mike        None         181 Baywood Lane     None
# 9   10       Allen    John D.        None   1052 Cannon Mill Drive     None
#
#             city state        zip  amount        date  candidate_id
# 0      Park City    UT  840683130    4600  2007-08-14            20
# 1  MIAMI SPRINGS    FL  331663832    2600  2008-01-25            37
# 2     Fort Smith    AR      72903    2300  2007-06-21            16
# 3    Hot Springs    AR      71913    2300  2007-06-12            16
# 4         Conway    AR      72034    2300  2007-04-11            16
# 5      Park City    UT  840683130    2300  2007-08-14            20
# 6         Camden    ME   48431752    2300  2007-09-30            20
# 7      SOUTHPORT    CT   68901376    2300  2007-09-14            35
# 8     Monticello    AR      71655    1500  2007-05-18            16
# 9  North Augusta    SC      29860    1300  2007-06-29            16

# %%
dfcwci[['first_name','amount']].head(10)
# Out:
#   first_name  amount
# 0     Steven     500
# 1        Don     250
# 2        Don      50
# 3        Don     100
# 4    Charles     100
# 5       Mike    1500
# 6    Rebecca     500
# 7    Brittni     250
# 8    John D.    1000
# 9    John D.    1300

# %%
out=make_query("SELECT first_name, amount FROM contributors;")
make_frame(out,['first_name','amount']).head(10)
# Out:
#   first_name  amount
# 0     Steven     500
# 1        Don     250
# 2        Don      50
# 3        Don     100
# 4    Charles     100
# 5       Mike    1500
# 6    Rebecca     500
# 7    Brittni     250
# 8    John D.    1000
# 9    John D.    1300

# %%
dfcwci[['last_name','first_name']].count()
# Out:
# last_name     175
# first_name    175
# dtype: int64

# %%
dfcwci[['last_name','first_name']].drop_duplicates().count()
# Out:
# last_name     126
# first_name    126
# dtype: int64

# %%
out = make_query("SELECT DISTINCT last_name, first_name FROM contributors;")
make_frame(out,['last_name','first_name']).head(10)
# Out:
#    last_name first_name
# 0     AARONS    CHARLES
# 1  ABACHERLI    SHIRLEY
# 2      ABAIR      PETER
# 3      ABATE      MARIA
# 4       ABBO    PAULINE
# 5      ABBOT      DAVID
# 6     ABBOTT     GERALD
# 7     ABBOTT       MIKE
# 8     ABBOTT     ROBERT
# 9     ABBOTT     RONALD

# %%
dfcwci['name'] = dfcwci["last_name"]+", "+dfcwci["first_name"]
dfcwci.head(10)
# Out:
#   last_name first_name middle_name                      street_1 street_2  \
# 0      Agee     Steven         NaN        549 Laurel Branch Road      NaN
# 1    Ahrens        Don         NaN          4034 Rennellwood Way      NaN
# 2    Ahrens        Don         NaN          4034 Rennellwood Way      NaN
# 3    Ahrens        Don         NaN          4034 Rennellwood Way      NaN
# 4      Akin    Charles         NaN        10187 Sugar Creek Road      NaN
# 5      Akin       Mike         NaN              181 Baywood Lane      NaN
# 6      Akin    Rebecca         NaN              181 Baywood Lane      NaN
# 7  Aldridge    Brittni         NaN  808 Capitol Square Place, SW      NaN
# 8     Allen    John D.         NaN        1052 Cannon Mill Drive      NaN
# 9     Allen    John D.         NaN        1052 Cannon Mill Drive      NaN
#
#             city state    zip  amount        date  candidate_id  \
# 0          Floyd    VA  24091     500  2007-06-30            16
# 1     Pleasanton    CA  94566     250  2007-05-16            16
# 2     Pleasanton    CA  94566      50  2007-06-18            16
# 3     Pleasanton    CA  94566     100  2007-06-21            16
# 4    Bentonville    AR  72712     100  2007-06-16            16
# 5     Monticello    AR  71655    1500  2007-05-18            16
# 6     Monticello    AR  71655     500  2007-05-18            16
# 7     Washington    DC  20024     250  2007-06-06            16
# 8  North Augusta    SC  29860    1000  2007-06-11            16
# 9  North Augusta    SC  29860    1300  2007-06-29            16
#
#                 name
# 0       Agee, Steven
# 1        Ahrens, Don
# 2        Ahrens, Don
# 3        Ahrens, Don
# 4      Akin, Charles
# 5         Akin, Mike
# 6      Akin, Rebecca
# 7  Aldridge, Brittni
# 8     Allen, John D.
# 9     Allen, John D.

# %%
dfcwci.assign(ucname=dfcwci.last_name+":"+dfcwci.first_name).head(10)
# Out:
#   last_name first_name middle_name                      street_1 street_2  \
# 0      Agee     Steven         NaN        549 Laurel Branch Road      NaN
# 1    Ahrens        Don         NaN          4034 Rennellwood Way      NaN
# 2    Ahrens        Don         NaN          4034 Rennellwood Way      NaN
# 3    Ahrens        Don         NaN          4034 Rennellwood Way      NaN
# 4      Akin    Charles         NaN        10187 Sugar Creek Road      NaN
# 5      Akin       Mike         NaN              181 Baywood Lane      NaN
# 6      Akin    Rebecca         NaN              181 Baywood Lane      NaN
# 7  Aldridge    Brittni         NaN  808 Capitol Square Place, SW      NaN
# 8     Allen    John D.         NaN        1052 Cannon Mill Drive      NaN
# 9     Allen    John D.         NaN        1052 Cannon Mill Drive      NaN
#
#             city state    zip  amount        date  candidate_id  \
# 0          Floyd    VA  24091     500  2007-06-30            16
# 1     Pleasanton    CA  94566     250  2007-05-16            16
# 2     Pleasanton    CA  94566      50  2007-06-18            16
# 3     Pleasanton    CA  94566     100  2007-06-21            16
# 4    Bentonville    AR  72712     100  2007-06-16            16
# 5     Monticello    AR  71655    1500  2007-05-18            16
# 6     Monticello    AR  71655     500  2007-05-18            16
# 7     Washington    DC  20024     250  2007-06-06            16
# 8  North Augusta    SC  29860    1000  2007-06-11            16
# 9  North Augusta    SC  29860    1300  2007-06-29            16
#
#                 name            ucname
# 0       Agee, Steven       Agee:Steven
# 1        Ahrens, Don        Ahrens:Don
# 2        Ahrens, Don        Ahrens:Don
# 3        Ahrens, Don        Ahrens:Don
# 4      Akin, Charles      Akin:Charles
# 5         Akin, Mike         Akin:Mike
# 6      Akin, Rebecca      Akin:Rebecca
# 7  Aldridge, Brittni  Aldridge:Brittni
# 8     Allen, John D.     Allen:John D.
# 9     Allen, John D.     Allen:John D.

# %%
dfcwci
# Out:
#        last_name first_name middle_name                      street_1  \
# 0           Agee     Steven         NaN        549 Laurel Branch Road
# 1         Ahrens        Don         NaN          4034 Rennellwood Way
# 2         Ahrens        Don         NaN          4034 Rennellwood Way
# 3         Ahrens        Don         NaN          4034 Rennellwood Way
# 4           Akin    Charles         NaN        10187 Sugar Creek Road
# 5           Akin       Mike         NaN              181 Baywood Lane
# 6           Akin    Rebecca         NaN              181 Baywood Lane
# 7       Aldridge    Brittni         NaN  808 Capitol Square Place, SW
# 8          Allen    John D.         NaN        1052 Cannon Mill Drive
# 9          Allen    John D.         NaN        1052 Cannon Mill Drive
# 10       Allison    John W.         NaN                 P.O. Box 1089
# 11       Allison    Rebecca         NaN             3206 Summit Court
# 12       Allison    Rebecca         NaN             3206 Summit Court
# 13         Altes       R.D.         NaN               8600 Moody Road
# 14        Andres       Dale         NaN          1160 Glen Oaks Drive
# 15       Anthony       John         NaN         211 Long Island Drive
# 16      Arbogast     Robert         NaN       12900 State Route 56 SE
# 17      Arbogast     Robert         NaN       12900 State Route 56 SE
# 18         Ardle    William         NaN             412 Dakota Avenue
# 19          Atiq       Omar         NaN           7200 S Hazel Street
# 20          Atiq       Omar         NaN           7200 S Hazel Street
# 21         Baker      David         NaN        2550 Adamsbrooke Drive
# 22      Bancroft      David         NaN         2934 Broderick Street
# 23         Banks    Charles         NaN               P.O. Box 251310
# 24        Barbee       John         NaN          516 Kellyridge Drive
# 25       Buckler      Steve         NaN               24351 Armada Dr
# 26       Buckler      Steve         NaN               24351 Armada Dr
# 27      Buckheit      Bruce         NaN                 8904 KAREN DR
# 28        Buckel      Linda         NaN                 PO Box 683130
# 29        Buckel      Linda         NaN                 PO Box 683130
# ..           ...        ...         ...                           ...
# 145      ABDELLA     THOMAS          M.   4231 MONUMENT WALL WAY #340
# 146       ABBOTT     WELDON          S.     777 EAST SOUTH TEMPLE  4E
# 147       ABBOTT     WELDON          S.     777 EAST SOUTH TEMPLE  4E
# 148       ABBOTT     GERALD          F.            389 BENEFIT STREET
# 149       ABBOTT     GERALD          F.            389 BENEFIT STREET
# 150       ABEDIN     ZAINUL         NaN         715 N. CENTRAL AVENUE
# 151       ABBOTT      SYBIL          F.               446 GAMES DRIVE
# 152       ABBOTT      SYBIL          F.               446 GAMES DRIVE
# 153       ABBOTT     RONALD     LEANDER         5453 HAWTHORNE STREET
# 154       ABBOTT     RONALD     LEANDER         5453 HAWTHORNE STREET
# 155       ABBOTT     ROBERT          A.               3061 LOREE ROAD
# 156       ABBOTT       MIKE          E.              4516 OSPREY LNDG
# 157        ABBOT      DAVID          M.               56 SALEM STREET
# 158         ABBO    PAULINE     MORENCY              10720 JACOB LANE
# 159        ABATE      MARIA       ELENA       1291 NIGHTINGALE AVENUE
# 160        ABAIR      PETER         NaN               40 EVANS STREET
# 161    ABACHERLI    SHIRLEY          M.            29875 NEWPORT ROAD
# 162       AARONS    CHARLES         NaN              1730 SHORE DRIVE
# 163       AARONS    CHARLES         NaN              1730 SHORE DRIVE
# 164       AARONS    CHARLES         NaN              1730 SHORE DRIVE
# 165         ABEL       JOHN          H.             422 THOMAS STREET
# 166         ABEL    MARLING          L.          14 HANGING MOSS LANE
# 167         ABEL    RUDOLPH         NaN              4532 OCEAN BLVD.
# 168        ABELE     RODNEY         NaN  3620 METAIRIE HEIGHTS AVENUE
# 169  ABERCROMBIE      DENIS         NaN            11811 WATER OAK CT
# 170     ABESHAUS    MERRILL          M.        1801 N. HEREFORD DRIVE
# 171      ABRAHAM     GEORGE         NaN                 P.O. BOX 1504
# 172   ABRAHAMSON      PETER          J.         1030 W. ROSCOE STREET
# 173      ABRAHAM      SALEM          A.                    P.O. BOX 7
# 174      ABRAHAM      SALEM          A.                    P.O. BOX 7
#
#       street_2             city state        zip  amount        date  \
# 0          NaN            Floyd    VA      24091     500  2007-06-30
# 1          NaN       Pleasanton    CA      94566     250  2007-05-16
# 2          NaN       Pleasanton    CA      94566      50  2007-06-18
# 3          NaN       Pleasanton    CA      94566     100  2007-06-21
# 4          NaN      Bentonville    AR      72712     100  2007-06-16
# 5          NaN       Monticello    AR      71655    1500  2007-05-18
# 6          NaN       Monticello    AR      71655     500  2007-05-18
# 7          NaN       Washington    DC      20024     250  2007-06-06
# 8          NaN    North Augusta    SC      29860    1000  2007-06-11
# 9          NaN    North Augusta    SC      29860    1300  2007-06-29
# 10         NaN           Conway    AR      72033    1000  2007-05-18
# 11         NaN      Little Rock    AR      72227    1000  2007-04-25
# 12         NaN      Little Rock    AR      72227     200  2007-06-12
# 13         NaN       Fort Smith    AR      72903    2300  2007-06-21
# 14         NaN  West Des Moines    IA      50266     250  2007-06-06
# 15         NaN      Hot Springs    AR      71913    2300  2007-06-12
# 16         NaN   Mount Sterling    OH      43143     500  2007-04-08
# 17         NaN   Mount Sterling    OH      43143     100  2007-06-22
# 18         NaN      Springfield    OH      45504      50  2007-06-28
# 19         NaN       Pine Bluff    AR      71603    1000  2007-05-18
# 20         NaN       Pine Bluff    AR      71603    1000  2007-06-27
# 21         NaN           Conway    AR      72034    2300  2007-04-11
# 22         NaN    San Francisco    CA      94123     250  2007-04-24
# 23         NaN      Little Rock    AR      72225    1000  2007-05-14
# 24         NaN             Apex    NC      27502     500  2007-05-23
# 25         NaN       Dana Point    CA  926291306      50  2007-07-30
# 26         NaN       Dana Point    CA  926291306      25  2007-08-16
# 27         NaN          FAIRFAX    VA  220312731     100  2007-09-19
# 28         NaN        Park City    UT  840683130    2300  2007-08-14
# 29         NaN        Park City    UT  840683130   -2300  2007-08-14
# ..         ...              ...   ...        ...     ...         ...
# 145        NaN          FAIRFAX    VA  220308440      50  2007-09-30
# 146        NaN   SALT LAKE CITY    UT  841021269     100  2007-09-29
# 147        NaN   SALT LAKE CITY    UT  841021269      50  2007-08-09
# 148        NaN       PROVIDENCE    RI   29032946     100  2007-09-15
# 149        NaN       PROVIDENCE    RI   29032946     100  2007-08-15
# 150  SUITE 212         GLENDALE    CA  912031164     500  2008-01-21
# 151        NaN             RENO    NV  895093326      75  2008-01-08
# 152        NaN             RENO    NV  895093326      50  2008-01-08
# 153        NaN        MONTCLAIR    CA  917632551     200  2008-01-31
# 154        NaN        MONTCLAIR    CA  917632551     100  2008-01-08
# 155        NaN      DECKERVILLE    MI  484279763     500  2008-01-21
# 156        NaN        NICEVILLE    FL  325786810    1000  2008-01-15
# 157        NaN          ANDOVER    MA   18102114     200  2008-01-21
# 158        NaN       WHITE LAKE    MI  483862274      35  2008-01-07
# 159        NaN    MIAMI SPRINGS    FL  331663832    2600  2008-01-25
# 160        NaN        WATERTOWN    MA   24722150      25  2008-01-09
# 161        NaN          MENIFEE    CA  925849524     150  2008-01-28
# 162        NaN        ANCHORAGE    AK  995153207     300  2008-01-30
# 163        NaN        ANCHORAGE    AK  995153207     410  2008-01-15
# 164        NaN        ANCHORAGE    AK  995153207     500  2008-01-09
# 165        NaN        BETHLEHEM    PA  180153316     200  2008-01-22
# 166        NaN       GREENVILLE    SC  296155069     100  2008-01-22
# 167      # 108         SARASOTA    FL  342421337     100  2008-01-08
# 168        NaN         METAIRIE    LA  700021823     500  2008-01-15
# 169        NaN         MAGNOLIA    TX  773546270     500  2008-01-30
# 170        NaN        FLAGSTAFF    AZ  860011121     120  2008-01-16
# 171        NaN     LAKE CHARLES    LA  706021504     800  2008-01-17
# 172        NaN          CHICAGO    IL  606572207      50  2008-01-25
# 173        NaN         CANADIAN    TX  790140007    1000  2008-01-17
# 174        NaN         CANADIAN    TX  790140007    1300  2008-01-30
#
#      candidate_id                name
# 0              16        Agee, Steven
# 1              16         Ahrens, Don
# 2              16         Ahrens, Don
# 3              16         Ahrens, Don
# 4              16       Akin, Charles
# 5              16          Akin, Mike
# 6              16       Akin, Rebecca
# 7              16   Aldridge, Brittni
# 8              16      Allen, John D.
# 9              16      Allen, John D.
# 10             16    Allison, John W.
# 11             16    Allison, Rebecca
# 12             16    Allison, Rebecca
# 13             16         Altes, R.D.
# 14             16        Andres, Dale
# 15             16       Anthony, John
# 16             16    Arbogast, Robert
# 17             16    Arbogast, Robert
# 18             16      Ardle, William
# 19             16          Atiq, Omar
# 20             16          Atiq, Omar
# 21             16        Baker, David
# 22             16     Bancroft, David
# 23             16      Banks, Charles
# 24             16        Barbee, John
# 25             20      Buckler, Steve
# 26             20      Buckler, Steve
# 27             20     Buckheit, Bruce
# 28             20       Buckel, Linda
# 29             20       Buckel, Linda
# ..            ...                 ...
# 145            35     ABDELLA, THOMAS
# 146            35      ABBOTT, WELDON
# 147            35      ABBOTT, WELDON
# 148            35      ABBOTT, GERALD
# 149            35      ABBOTT, GERALD
# 150            37      ABEDIN, ZAINUL
# 151            37       ABBOTT, SYBIL
# 152            37       ABBOTT, SYBIL
# 153            37      ABBOTT, RONALD
# 154            37      ABBOTT, RONALD
# 155            37      ABBOTT, ROBERT
# 156            37        ABBOTT, MIKE
# 157            37        ABBOT, DAVID
# 158            37       ABBO, PAULINE
# 159            37        ABATE, MARIA
# 160            37        ABAIR, PETER
# 161            37  ABACHERLI, SHIRLEY
# 162            37     AARONS, CHARLES
# 163            37     AARONS, CHARLES
# 164            37     AARONS, CHARLES
# 165            37          ABEL, JOHN
# 166            37       ABEL, MARLING
# 167            37       ABEL, RUDOLPH
# 168            37       ABELE, RODNEY
# 169            37  ABERCROMBIE, DENIS
# 170            37   ABESHAUS, MERRILL
# 171            37     ABRAHAM, GEORGE
# 172            37   ABRAHAMSON, PETER
# 173            37      ABRAHAM, SALEM
# 174            37      ABRAHAM, SALEM
#
# [175 rows x 12 columns]

# %%
dfcwci[dfcwci.state=='VA']
# Out:
#      last_name first_name middle_name                     street_1 street_2  \
# 0         Agee     Steven         NaN       549 Laurel Branch Road      NaN
# 27    Buckheit      Bruce         NaN                8904 KAREN DR      NaN
# 77   Ranganath      Anoop         NaN           2507 Willard Drive      NaN
# 88   Perreault     Louise         NaN    503 Brockridge Hunt Drive      NaN
# 145    ABDELLA     THOMAS          M.  4231 MONUMENT WALL WAY #340      NaN
#
#                 city state        zip  amount        date  candidate_id  \
# 0              Floyd    VA      24091  500.00  2007-06-30            16
# 27           FAIRFAX    VA  220312731  100.00  2007-09-19            20
# 77   Charlottesville    VA      22903 -100.00  2008-04-21            32
# 88           Hampton    VA      23666  -34.08  2008-04-21            32
# 145          FAIRFAX    VA  220308440   50.00  2007-09-30            35
#
#                   name
# 0         Agee, Steven
# 27     Buckheit, Bruce
# 77    Ranganath, Anoop
# 88   Perreault, Louise
# 145    ABDELLA, THOMAS

# %%
dfcwci.loc[dfcwci.state=='VA','name']
# Out:
# 0           Agee, Steven
# 27       Buckheit, Bruce
# 77      Ranganath, Anoop
# 88     Perreault, Louise
# 145      ABDELLA, THOMAS
# Name: name, dtype: object

# %%
dfcwci.loc[dfcwci.state=='VA','name']="junk"

# %%
dfcwci.query("state=='VA'")
# Out:
#      last_name first_name middle_name                     street_1 street_2  \
# 0         Agee     Steven         NaN       549 Laurel Branch Road      NaN
# 27    Buckheit      Bruce         NaN                8904 KAREN DR      NaN
# 77   Ranganath      Anoop         NaN           2507 Willard Drive      NaN
# 88   Perreault     Louise         NaN    503 Brockridge Hunt Drive      NaN
# 145    ABDELLA     THOMAS          M.  4231 MONUMENT WALL WAY #340      NaN
#
#                 city state        zip  amount        date  candidate_id  name
# 0              Floyd    VA      24091  500.00  2007-06-30            16  junk
# 27           FAIRFAX    VA  220312731  100.00  2007-09-19            20  junk
# 77   Charlottesville    VA      22903 -100.00  2008-04-21            32  junk
# 88           Hampton    VA      23666  -34.08  2008-04-21            32  junk
# 145          FAIRFAX    VA  220308440   50.00  2007-09-30            35  junk

# %%
alt="ALTER TABLE contributors ADD COLUMN name;"
db.cursor().execute(alt)

# %%
make_query("PRAGMA table_info(contributors);")
# Out:
# [(0, u'id', u'INTEGER', 1, None, 1),
#  (1, u'last_name', u'VARCHAR', 0, None, 0),
#  (2, u'first_name', u'VARCHAR', 0, None, 0),
#  (3, u'middle_name', u'VARCHAR', 0, None, 0),
#  (4, u'street_1', u'VARCHAR', 0, None, 0),
#  (5, u'street_2', u'VARCHAR', 0, None, 0),
#  (6, u'city', u'VARCHAR', 0, None, 0),
#  (7, u'state', u'VARCHAR', 0, None, 0),
#  (8, u'zip', u'VARCHAR', 0, None, 0),
#  (9, u'amount', u'INTEGER', 0, None, 0),
#  (10, u'date', u'DATETIME', 0, None, 0),
#  (11, u'candidate_id', u'INTEGER', 1, None, 0),
#  (12, u'name', u'', 0, None, 0)]

# %%
out = make_query("SELECT id, last_name,first_name from contributors;")
out2 = [(e[1]+", "+e[2],e[0]) for e in out]
out2
# Out:
# [(u'Agee, Steven', 1),
#  (u'Ahrens, Don', 2),
#  (u'Ahrens, Don', 3),
#  (u'Ahrens, Don', 4),
#  (u'Akin, Charles', 5),
#  (u'Akin, Mike', 6),
#  (u'Akin, Rebecca', 7),
#  (u'Aldridge, Brittni', 8),
#  (u'Allen, John D.', 9),
#  (u'Allen, John D.', 10),
#  (u'Allison, John W.', 11),
#  (u'Allison, Rebecca', 12),
#  (u'Allison, Rebecca', 13),
#  (u'Altes, R.D.', 14),
#  (u'Andres, Dale', 15),
#  (u'Anthony, John', 16),
#  (u'Arbogast, Robert', 17),
#  (u'Arbogast, Robert', 18),
#  (u'Ardle, William', 19),
#  (u'Atiq, Omar', 20),
#  (u'Atiq, Omar', 21),
#  (u'Baker, David', 22),
#  (u'Bancroft, David', 23),
#  (u'Banks, Charles', 24),
#  (u'Barbee, John', 25),
#  (u'Buckler, Steve', 26),
#  (u'Buckler, Steve', 27),
#  (u'Buckheit, Bruce', 28),
#  (u'Buckel, Linda', 29),
#  (u'Buckel, Linda', 30),
#  (u'Buckel, Linda', 31),
#  (u'Buck, Thomas', 32),
#  (u'Buck, Jay', 33),
#  (u'Buck, Blaine', 34),
#  (u'Buck, Barbara', 35),
#  (u'Buck, Barbara', 36),
#  (u'Buchman, Mark M', 37),
#  (u'Bucher, Ida', 38),
#  (u'Buchanek, Elizabeth', 39),
#  (u'Buchanan, John', 40),
#  (u'Buchanan, John', 41),
#  (u'Buchanan, John', 42),
#  (u'Buchanan, John', 43),
#  (u'Buchanan, John', 44),
#  (u'Buchanan, John', 45),
#  (u'Buchanan, John', 46),
#  (u'Buchanan, John', 47),
#  (u'Buchanan, John', 48),
#  (u'Buchanan, John', 49),
#  (u'Harrison, Ryan', 50),
#  (u'BYNUM, HERBERT', 51),
#  (u'BYINGTON, MARGARET', 52),
#  (u'BYERS, BOB', 53),
#  (u'BYERS, AUDREY', 54),
#  (u'BUSH, KRYSTIE', 55),
#  (u'BUSH, ERIC', 56),
#  (u'BURTON, SUSAN', 57),
#  (u'BURTON, STEVEN', 58),
#  (u'BURTON, GLENN', 59),
#  (u'BURKHARDT, CRAIG', 60),
#  (u'BURKHARDT, CRAIG', 61),
#  (u'BURKHARDT, BARBARA', 62),
#  (u'BURKE, SUZANNE', 63),
#  (u'BURKE, GAIL', 64),
#  (u'BURKE, DONALD', 65),
#  (u'BURGERT, RONALD', 66),
#  (u'BULL, BARTLE', 67),
#  (u'BULL, BARTLE', 68),
#  (u'BUKOWSKI, DANIEL', 69),
#  (u'BUISSON, MARGARET', 70),
#  (u'BUCKLEY, WALTER', 71),
#  (u'BUCKLEY, MARJORIE', 72),
#  (u'BRUNO, JOHN', 73),
#  (u'BRUNO, IRENE', 74),
#  (u'BROWN, TIMOTHY', 75),
#  (u'Schuff, Bryan', 76),
#  (u'Hobbs, James', 77),
#  (u'Ranganath, Anoop', 78),
#  (u'Nystrom, Michael', 79),
#  (u'Muse, Nina', 80),
#  (u'Waddell, James', 81),
#  (u'Brucks, William', 82),
#  (u'Kuehn, David', 83),
#  (u'Verster, Jeanette', 84),
#  (u'Uihlein, Richard', 85),
#  (u'Eskenberry, Robert', 86),
#  (u'Froehling, Alan', 87),
#  (u'Duryea, Marcia', 88),
#  (u'Perreault, Louise', 89),
#  (u'Rozenfeld, Timur', 90),
#  (u'Kazor, Christopher', 91),
#  (u'Lehner, Thomas', 92),
#  (u'Plummer, Joseph', 93),
#  (u'Raught, Philip', 94),
#  (u'Ferrara, Judith', 95),
#  (u'Johnson, Cathleen', 96),
#  (u'Sanford, Bradley', 97),
#  (u'Gaarder, Bruce', 98),
#  (u'Choe, Hyeokchan', 99),
#  (u'Jacobs, Richard', 100),
#  (u'Aaronson, Rebecca', 101),
#  (u'Aarons, Elaine', 102),
#  (u'Aarons, Elaine', 103),
#  (u'Aarons, Elaine', 104),
#  (u'Aaron, Shirley', 105),
#  (u'Aaron, Shirley', 106),
#  (u'Aaronson, Rebecca', 107),
#  (u'Aaron, Shirley', 108),
#  (u'Aaron, Shirley', 109),
#  (u'Aaron, Shirley', 110),
#  (u'Reid, Elizabeth', 111),
#  (u'Reich, Thomas', 112),
#  (u'Aaron, Shirley', 113),
#  (u'Aaron, Shirley', 114),
#  (u'Aaron, Sharron', 115),
#  (u'Aaron, Patricia', 116),
#  (u'Aaron, Patricia', 117),
#  (u'Aaron, Jim', 118),
#  (u'Aaron, Jim', 119),
#  (u'Aaron, Carole', 120),
#  (u'Aaron, Carole', 121),
#  (u'Aaron, Carole', 122),
#  (u'Aaron, Barbara', 123),
#  (u'Aanonsen, Lin', 124),
#  (u'Aanonsen, Lin', 125),
#  (u'BOURNE, TRAVIS', 126),
#  (u'SECRIST, BRIAN', 127),
#  (u'TOLLESTRUP, TRAVIS', 128),
#  (u'ACCORD, DEAN', 129),
#  (u'ABTS, HENRY', 130),
#  (u'ABSHIER, LANNY', 131),
#  (u'ABSHIER, DIANA', 132),
#  (u'ABREU, KEVIN', 133),
#  (u'ABREU, KEVIN', 134),
#  (u'ABREU, KEVIN', 135),
#  (u'ABRAMOWITZ, NIRA', 136),
#  (u'ABRAMS, MICHAEL', 137),
#  (u'ABRAMOWITZ, KEN', 138),
#  (u'ABOUBAKARE, NASAR', 139),
#  (u'ABEGG, PATRICIA', 140),
#  (u'ABEGG, PATRICIA', 141),
#  (u'ABEGG, PATRICIA', 142),
#  (u'ABEGG, PATRICIA', 143),
#  (u'ABEGG, PATRICIA', 144),
#  (u'ABEGG, PATRICIA', 145),
#  (u'ABDELLA, THOMAS', 146),
#  (u'ABBOTT, WELDON', 147),
#  (u'ABBOTT, WELDON', 148),
#  (u'ABBOTT, GERALD', 149),
#  (u'ABBOTT, GERALD', 150),
#  (u'ABEDIN, ZAINUL', 151),
#  (u'ABBOTT, SYBIL', 152),
#  (u'ABBOTT, SYBIL', 153),
#  (u'ABBOTT, RONALD', 154),
#  (u'ABBOTT, RONALD', 155),
#  (u'ABBOTT, ROBERT', 156),
#  (u'ABBOTT, MIKE', 157),
#  (u'ABBOT, DAVID', 158),
#  (u'ABBO, PAULINE', 159),
#  (u'ABATE, MARIA', 160),
#  (u'ABAIR, PETER', 161),
#  (u'ABACHERLI, SHIRLEY', 162),
#  (u'AARONS, CHARLES', 163),
#  (u'AARONS, CHARLES', 164),
#  (u'AARONS, CHARLES', 165),
#  (u'ABEL, JOHN', 166),
#  (u'ABEL, MARLING', 167),
#  (u'ABEL, RUDOLPH', 168),
#  (u'ABELE, RODNEY', 169),
#  (u'ABERCROMBIE, DENIS', 170),
#  (u'ABESHAUS, MERRILL', 171),
#  (u'ABRAHAM, GEORGE', 172),
#  (u'ABRAHAMSON, PETER', 173),
#  (u'ABRAHAM, SALEM', 174),
#  (u'ABRAHAM, SALEM', 175)]

# %%
alt2="UPDATE contributors SET name = ? WHERE id = ?;"
for ele in out2:
    db.cursor().execute(alt2, ele)

# %%
db.commit()

# %%
out = make_query("SELECT * from contributors;")
make_frame(out,cont_cols+["name"]).head(10)
# Out:
#    id last_name first_name middle_name                      street_1 street_2  \
# 0   1      Agee     Steven        None        549 Laurel Branch Road     None
# 1   2    Ahrens        Don        None          4034 Rennellwood Way     None
# 2   3    Ahrens        Don        None          4034 Rennellwood Way     None
# 3   4    Ahrens        Don        None          4034 Rennellwood Way     None
# 4   5      Akin    Charles        None        10187 Sugar Creek Road     None
# 5   6      Akin       Mike        None              181 Baywood Lane     None
# 6   7      Akin    Rebecca        None              181 Baywood Lane     None
# 7   8  Aldridge    Brittni        None  808 Capitol Square Place, SW     None
# 8   9     Allen    John D.        None        1052 Cannon Mill Drive     None
# 9  10     Allen    John D.        None        1052 Cannon Mill Drive     None
#
#             city state    zip  amount        date  candidate_id  \
# 0          Floyd    VA  24091     500  2007-06-30            16
# 1     Pleasanton    CA  94566     250  2007-05-16            16
# 2     Pleasanton    CA  94566      50  2007-06-18            16
# 3     Pleasanton    CA  94566     100  2007-06-21            16
# 4    Bentonville    AR  72712     100  2007-06-16            16
# 5     Monticello    AR  71655    1500  2007-05-18            16
# 6     Monticello    AR  71655     500  2007-05-18            16
# 7     Washington    DC  20024     250  2007-06-06            16
# 8  North Augusta    SC  29860    1000  2007-06-11            16
# 9  North Augusta    SC  29860    1300  2007-06-29            16
#
#                 name
# 0       Agee, Steven
# 1        Ahrens, Don
# 2        Ahrens, Don
# 3        Ahrens, Don
# 4      Akin, Charles
# 5         Akin, Mike
# 6      Akin, Rebecca
# 7  Aldridge, Brittni
# 8     Allen, John D.
# 9     Allen, John D.

# %%
upd="UPDATE contributors SET name = 'junk' WHERE state = 'VA';"
db.cursor().execute(upd)
db.commit()

# %%
out=make_query("SELECT * from contributors where state='VA';")
make_frame(out,cont_cols+["name"]).head(10)
# Out:
#     id  last_name first_name middle_name                     street_1  \
# 0    1       Agee     Steven        None       549 Laurel Branch Road
# 1   28   Buckheit      Bruce        None                8904 KAREN DR
# 2   78  Ranganath      Anoop        None           2507 Willard Drive
# 3   89  Perreault     Louise        None    503 Brockridge Hunt Drive
# 4  146    ABDELLA     THOMAS          M.  4231 MONUMENT WALL WAY #340
#
#   street_2             city state        zip  amount        date  \
# 0     None            Floyd    VA      24091  500.00  2007-06-30
# 1     None          FAIRFAX    VA  220312731  100.00  2007-09-19
# 2     None  Charlottesville    VA      22903 -100.00  2008-04-21
# 3     None          Hampton    VA      23666  -34.08  2008-04-21
# 4     None          FAIRFAX    VA  220308440   50.00  2007-09-30
#
#    candidate_id  name
# 0            16  junk
# 1            20  junk
# 2            32  junk
# 3            32  junk
# 4            35  junk

# %%
dfcwci.describe()
# Out:
#                 zip       amount  candidate_id
# count  1.750000e+02   175.000000    175.000000
# mean   3.780014e+08     3.418114     28.000000
# std    3.628278e+08  1028.418999      7.823484
# min    2.474000e+03 -2592.000000     16.000000
# 25%    9.336700e+04  -175.000000     20.000000
# 50%    3.233313e+08   100.000000     32.000000
# 75%    7.816946e+08   300.000000     35.000000
# max    9.951532e+08  4600.000000     37.000000

# %%
dfcwci.amount.max()
# Out:
# 4600.0

# %%
dfcwci[dfcwci.amount==dfcwci.amount.max()]
# Out:
#    last_name first_name middle_name       street_1 street_2       city state  \
# 30    Buckel      Linda         NaN  PO Box 683130      NaN  Park City    UT
#
#           zip  amount        date  candidate_id           name
# 30  840683130    4600  2007-08-14            20  Buckel, Linda

# %%
out=make_query("SELECT *, MAX(amount) AS maxamt FROM contributors;")
print out
make_frame(out,cont_cols+["maxamt"])
# Out:
# [(175, u'ABRAHAM', u'SALEM', u'A.', u'P.O. BOX 7', None, u'CANADIAN', u'TX', u'790140007', 1300, u'2008-01-30', 37, u'ABRAHAM, SALEM', 4600)]
#     id last_name first_name middle_name    street_1 street_2      city state  \
# 0  175   ABRAHAM      SALEM          A.  P.O. BOX 7     None  CANADIAN    TX
#
#          zip  amount        date  candidate_id          maxamt
# 0  790140007    1300  2008-01-30            37  ABRAHAM, SALEM

# %%
out=make_query("SELECT COUNT(amount) AS AMOUNTCOUNT FROM contributors;")
print out
# Out:
# [(175,)]

# %%
out=make_query("SELECT AVG(amount) FROM contributors")
print out
# Out:
# [(3.418114285714276,)]

# %%
dfcwci.groupby("state").sum()
# Out:
#                zip    amount  candidate_id
# state
# AK      2985459621   1210.00           111
# AR          864790  14200.00           192
# AZ       860011121    120.00            37
# CA     14736360720  -5013.73           600
# CO      2405477834  -5823.00           111
# CT        68901376   2300.00            35
# DC       800341853  -1549.91           102
# FL      8970626520  -4050.00           803
# IA           50266    250.00            16
# ID           83648   -261.00            32
# IL      3042068689  -5586.80           175
# KS           66215   -330.00            32
# KY       402597029   -200.00            22
# LA      1406043327   1300.00            74
# MA       123026638    -83.00           208
# MD       416287617    300.00            55
# ME       165647170   2520.00           122
# MI      2426973485  -1265.00           164
# MN      1102338918    322.00           100
# MO           64111    100.00            20
# NC           27502    500.00            16
# NH        32564424    -24.60            32
# NJ        70254993   -817.45            64
# NV      3575889763    725.00           144
# NY       606129991  -6474.50           233
# OH          176071    450.00            80
# OK      2202499044    800.00           102
# PA       540499020  -2146.00           145
# RI        58065892    200.00            70
# SC       296214789   2400.00            69
# TN           37188    -25.00            32
# TX      6221452245   1985.24           302
# UT      9251153394   5050.00           340
# VA       440691831    515.92           135
# WA      2941290251   -500.00            90

# %%
dfcwci.groupby("state")['amount'].mean()
# Out:
# state
# AK     403.333333
# AR    1183.333333
# AZ     120.000000
# CA    -217.988261
# CO   -1455.750000
# CT    2300.000000
# DC    -309.982000
# FL    -135.000000
# IA     250.000000
# ID    -261.000000
# IL    -931.133333
# KS    -330.000000
# KY    -200.000000
# LA     650.000000
# MA     -13.833333
# MD     150.000000
# ME     630.000000
# MI    -253.000000
# MN     107.333333
# MO     100.000000
# NC     500.000000
# NH     -24.600000
# NJ    -408.725000
# NV     181.250000
# NY    -809.312500
# OH     112.500000
# OK     266.666667
# PA    -429.200000
# RI     100.000000
# SC     800.000000
# TN     -25.000000
# TX     220.582222
# UT     459.090909
# VA     103.184000
# WA    -166.666667
# Name: amount, dtype: float64

# %%
dfcwci.state.unique()
# Out:
# array(['VA', 'CA', 'AR', 'DC', 'SC', 'IA', 'OH', 'NC', 'UT', 'MO', 'IL',
#        'ME', 'FL', 'MD', 'MI', 'CO', 'WA', 'NY', 'TX', 'KY', 'PA', 'TN',
#        'MA', 'MN', 'KS', 'NJ', 'NH', 'ID', 'OK', nan, 'NV', 'CT', 'RI',
#        'AK', 'LA', 'AZ'], dtype=object)

# %%
out=make_query("SELECT state,SUM(amount) FROM contributors GROUP BY state;")
make_frame(out,legend=['state','sum'])
# Out:
#    state       sum
# 0   None   -500.00
# 1     AK   1210.00
# 2     AR  14200.00
# 3     AZ    120.00
# 4     CA  -5013.73
# 5     CO  -5823.00
# 6     CT   2300.00
# 7     DC  -1549.91
# 8     FL  -4050.00
# 9     IA    250.00
# 10    ID   -261.00
# 11    IL  -5586.80
# 12    KS   -330.00
# 13    KY   -200.00
# 14    LA   1300.00
# 15    MA    -83.00
# 16    MD    300.00
# 17    ME   2520.00
# 18    MI  -1265.00
# 19    MN    322.00
# 20    MO    100.00
# 21    NC    500.00
# 22    NH    -24.60
# 23    NJ   -817.45
# 24    NV    725.00
# 25    NY  -6474.50
# 26    OH    450.00
# 27    OK    800.00
# 28    PA  -2146.00
# 29    RI    200.00
# 30    SC   2400.00
# 31    TN    -25.00
# 32    TX   1985.24
# 33    UT   5050.00
# 34    VA    515.92
# 35    WA   -500.00

# %%
dfcwci.head()
# Out:
#   last_name first_name middle_name                street_1 street_2  \
# 0      Agee     Steven         NaN  549 Laurel Branch Road      NaN
# 1    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 2    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 3    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 4      Akin    Charles         NaN  10187 Sugar Creek Road      NaN
#
#           city state    zip  amount        date  candidate_id           name
# 0        Floyd    VA  24091     500  2007-06-30            16           junk
# 1   Pleasanton    CA  94566     250  2007-05-16            16    Ahrens, Don
# 2   Pleasanton    CA  94566      50  2007-06-18            16    Ahrens, Don
# 3   Pleasanton    CA  94566     100  2007-06-21            16    Ahrens, Don
# 4  Bentonville    AR  72712     100  2007-06-16            16  Akin, Charles

# %%
df2 = dfcwci.copy()
df2.set_index('last_name', inplace=True)
df2.head()
# Out:
#           first_name middle_name                street_1 street_2  \
# last_name
# Agee          Steven         NaN  549 Laurel Branch Road      NaN
# Ahrens           Don         NaN    4034 Rennellwood Way      NaN
# Ahrens           Don         NaN    4034 Rennellwood Way      NaN
# Ahrens           Don         NaN    4034 Rennellwood Way      NaN
# Akin         Charles         NaN  10187 Sugar Creek Road      NaN
#
#                   city state    zip  amount        date  candidate_id  \
# last_name
# Agee             Floyd    VA  24091     500  2007-06-30            16
# Ahrens      Pleasanton    CA  94566     250  2007-05-16            16
# Ahrens      Pleasanton    CA  94566      50  2007-06-18            16
# Ahrens      Pleasanton    CA  94566     100  2007-06-21            16
# Akin       Bentonville    AR  72712     100  2007-06-16            16
#
#                     name
# last_name
# Agee                junk
# Ahrens       Ahrens, Don
# Ahrens       Ahrens, Don
# Ahrens       Ahrens, Don
# Akin       Akin, Charles

# %%
df2.drop(['Ahrens'],inplace=True)
df2.head()
# Out:
#           first_name middle_name                      street_1 street_2  \
# last_name
# Agee          Steven         NaN        549 Laurel Branch Road      NaN
# Akin         Charles         NaN        10187 Sugar Creek Road      NaN
# Akin            Mike         NaN              181 Baywood Lane      NaN
# Akin         Rebecca         NaN              181 Baywood Lane      NaN
# Aldridge     Brittni         NaN  808 Capitol Square Place, SW      NaN
#
#                   city state    zip  amount        date  candidate_id  \
# last_name
# Agee             Floyd    VA  24091     500  2007-06-30            16
# Akin       Bentonville    AR  72712     100  2007-06-16            16
# Akin        Monticello    AR  71655    1500  2007-05-18            16
# Akin        Monticello    AR  71655     500  2007-05-18            16
# Aldridge    Washington    DC  20024     250  2007-06-06            16
#
#                         name
# last_name
# Agee                    junk
# Akin           Akin, Charles
# Akin              Akin, Mike
# Akin           Akin, Rebecca
# Aldridge   Aldridge, Brittni

# %%
df2.reset_index(inplace=True)
df2.head()
# Out:
#    index last_name first_name middle_name                      street_1  \
# 0      0      Agee     Steven         NaN        549 Laurel Branch Road
# 1      1      Akin    Charles         NaN        10187 Sugar Creek Road
# 2      2      Akin       Mike         NaN              181 Baywood Lane
# 3      3      Akin    Rebecca         NaN              181 Baywood Lane
# 4      4  Aldridge    Brittni         NaN  808 Capitol Square Place, SW
#
#   street_2         city state    zip  amount        date  candidate_id  \
# 0      NaN        Floyd    VA  24091     500  2007-06-30            16
# 1      NaN  Bentonville    AR  72712     100  2007-06-16            16
# 2      NaN   Monticello    AR  71655    1500  2007-05-18            16
# 3      NaN   Monticello    AR  71655     500  2007-05-18            16
# 4      NaN   Washington    DC  20024     250  2007-06-06            16
#
#                 name
# 0               junk
# 1      Akin, Charles
# 2         Akin, Mike
# 3      Akin, Rebecca
# 4  Aldridge, Brittni

# %%
out = make_query("SELECT * FROM contributors LIMIT 3;")
make_frame(out).head(10)
# Out:
#    id last_name first_name middle_name                street_1 street_2  \
# 0   1      Agee     Steven        None  549 Laurel Branch Road     None
# 1   2    Ahrens        Don        None    4034 Rennellwood Way     None
# 2   3    Ahrens        Don        None    4034 Rennellwood Way     None
#
#          city state    zip  amount        date  candidate_id
# 0       Floyd    VA  24091     500  2007-06-30            16
# 1  Pleasanton    CA  94566     250  2007-05-16            16
# 2  Pleasanton    CA  94566      50  2007-06-18            16

# %%
dfcwci[0:3]
# Out:
#   last_name first_name middle_name                street_1 street_2  \
# 0      Agee     Steven         NaN  549 Laurel Branch Road      NaN
# 1    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 2    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
#
#          city state    zip  amount        date  candidate_id         name
# 0       Floyd    VA  24091     500  2007-06-30            16         junk
# 1  Pleasanton    CA  94566     250  2007-05-16            16  Ahrens, Don
# 2  Pleasanton    CA  94566      50  2007-06-18            16  Ahrens, Don

# %%
crind="CREATE INDEX amount_ix ON contributors(amount);"
db.cursor().execute(crind)
db.commit()

# %%
dfcand.head()
# Out:
#    id   first_name  last_name middle_name party
# 0  33       Joseph      Biden         NaN     D
# 1  36       Samuel  Brownback         NaN     R
# 2  34      Hillary    Clinton          R.     D
# 3  39  Christopher       Dodd          J.     D
# 4  26         John    Edwards         NaN     D

# %%
obamaid=dfcand.query("last_name=='Obama'")["id"].values[0]

# %%
obamacontrib=dfcwci.query("candidate_id==%i" % obamaid)
obamacontrib.head()
# Out:
#    id last_name first_name middle_name                street_1 street_2  \
# 0 NaN      Agee     Steven         NaN  549 Laurel Branch Road      NaN
# 1 NaN    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 2 NaN    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 3 NaN    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 4 NaN      Akin    Charles         NaN  10187 Sugar Creek Road      NaN
#
#           city state    zip  amount        date  candidate_id
# 0        Floyd    VA  24091     500  2007-06-30            33
# 1   Pleasanton    CA  94566     250  2007-05-16            33
# 2   Pleasanton    CA  94566      50  2007-06-18            33
# 3   Pleasanton    CA  94566     100  2007-06-21            33
# 4  Bentonville    AR  72712     100  2007-06-16            33

# %%
russiandollsel="""
SELECT * FROM contributors WHERE
    candidate_id = (SELECT id from candidates WHERE last_name = 'Obama');
"""
